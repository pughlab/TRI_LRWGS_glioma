# %%
import matplotlib.pyplot as plt

# %%
import os
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib as mpl

# %%
pd.options.display.max_rows = 200

# %%
burden_dict = \
{'E_P_GBM454': 2.567235,
 'J_R_SMTB781': 3.4093850000000003,
 'X_R_SMTB302': 4.067572,
 'B_R_GBM898': 4.9197310000000005,
 'D_P_GBM620': 6.767882999999999,
 'X_R_SMTB135': 7.804867999999999,
 'X_P_GBM618': 8.284311000000002,
 'C_R_GBM781': 23.332295,
 'B_P_GBM593': 38.391685999999986,
 'A_R_GBM607': 46.18504800000001,
 'H_P_GBM529': 58.749589,
 'C_RR_GBM937': 62.922092,
 'A_RR_GBM809': 75.85607500000002,
 'J_P_GBM703': 78.30020900000001,
 'D_R_GBM691': 80.84621199999998,
 'X_P_GBM672': 100.40625700000002,
 'I_P_BT2013110': 104.15168,
 'E_R_GBM833': 135.700069,
 'G_P_GBM401': 141.95874999999995,
 'I_R_GBM745': 183.607591,
 'X_P_GBM440': 186.296958,
 'X_P_GBM577': 274.53248799999994,
 'X_R_SMTB814': 288.11394000000007,
 'X_R_SMTB241': 351.32789599999995,
 'G_RR_GBM551': 373.39768200000003,
 'X_P_SMTB123': 384.9045270000001,
 'G_R_GBM498': 405.05991099999994,
 'F_R_GBM492': 488.609452,
 'F_P_GBM460': 509.9145350000001,
 'X_R_GBM945': 582.347414,
 'H_R_GBM832': 696.6370109999999}

# %%
low_burden_sample_id = list(burden_dict.keys())[:15]
high_burden_sample_id = list(burden_dict.keys())[15:]

# %%
def calculate_total_coverage(df):
    
    if len(df) == 0:
        
        return 0
    
    # Ensure the dataframe is sorted by the start of intervals
    df_sorted = df.sort_values(by='POS')
    
    # Initialize the variables to track the merged intervals
    merged_start = df_sorted.iloc[0]['POS']
    merged_end = df_sorted.iloc[0]['END']
    total_coverage = 0
    
    # Iterate over the sorted dataframe
    for _, row in df_sorted.iterrows():
        current_start, current_end = row['POS'], row['END']
        
        # If the current interval overlaps with the merged interval, extend the merged interval
        if current_start <= merged_end:
            merged_end = max(merged_end, current_end)
        else:
            # No overlap, finalize the current merged interval
            total_coverage += merged_end - merged_start
            # Start a new merged interval
            merged_start, merged_end = current_start, current_end
    
    # Add the last interval to total coverage
    total_coverage += merged_end - merged_start
    
    return total_coverage

# %%
chromosomes = ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', \
               'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', \
               'chr21', 'chr22', 'chrX']

# %% [markdown]
# ## Large deletions

# %%
### Load filtered large deletions ###

##
somatic_large_DEL_path = '/Users/ryanyutian/Desktop/Manuscript/filtered_sv/DEL/'

somatic_large_DEL_dfs = {}

os.chdir(somatic_large_DEL_path)

temp_files = sorted([i for i in os.listdir(somatic_large_DEL_path) if 'DS' not in i])

for file_name in temp_files:
        
    somatic_large_DEL_dfs[file_name[:-4]] = pd.read_csv(file_name)

# %%
large_DEL_burden_per_chrom_dicts = {}

for df_name in somatic_large_DEL_dfs:
    
    temp_output_dict = {}
    
    temp_df = somatic_large_DEL_dfs[df_name]
    
    for chrom in chromosomes:
        
        temp_chrom_df = temp_df[temp_df['CHROM']==chrom]
        
        temp_output_dict[chrom] = calculate_total_coverage(temp_chrom_df)/1e6
        
    large_DEL_burden_per_chrom_dicts[df_name + '_burden_by_chrom'] = temp_output_dict

# %%
large_DEL_burden_per_chrom_dicts
# Out:
# {'A_RR_GBM809_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.1,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.066223,
#   'chr11': 2.57,
#   'chr12': 0.031164,
#   'chr13': 1.272043,
#   'chr14': 0.59,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'A_R_GBM607_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.03007,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.04647,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'B_P_GBM593_DEL_burden_by_chrom': {'chr1': 0.11,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.23,
#   'chr7': 0.090319,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.055101,
#   'chr13': 1.87,
#   'chr14': 0.038349,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.11},
#  'B_R_GBM898_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.05685,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.22892,
#   'chr13': 0.0,
#   'chr14': 0.038364,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.146849,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.040938},
#  'C_RR_GBM937_DEL_burden_by_chrom': {'chr1': 0.216541,
#   'chr2': 1.78,
#   'chr3': 2.895935,
#   'chr4': 8.09,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.243471,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.292244,
#   'chr11': 3.71,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.76,
#   'chr16': 0.337079,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.08,
#   'chr21': 0.170584,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'C_R_GBM781_DEL_burden_by_chrom': {'chr1': 0.11,
#   'chr2': 0.040142,
#   'chr3': 0.959634,
#   'chr4': 0.0,
#   'chr5': 0.225212,
#   'chr6': 0.0,
#   'chr7': 0.090389,
#   'chr8': 0.0,
#   'chr9': 11.132734,
#   'chr10': 0.0,
#   'chr11': 4.79,
#   'chr12': 0.0,
#   'chr13': 0.489696,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.149304},
#  'D_P_GBM620_DEL_burden_by_chrom': {'chr1': 1.66,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.0,
#   'chr8': 0.0,
#   'chr9': 0.41,
#   'chr10': 1.2,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.42042,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.046943,
#   'chr17': 0.0,
#   'chr18': 0.163748,
#   'chr19': 0.052444,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'D_R_GBM691_DEL_burden_by_chrom': {'chr1': 0.13,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.564246,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.430163,
#   'chr8': 0.0,
#   'chr9': 2.35,
#   'chr10': 0.48,
#   'chr11': 0.0,
#   'chr12': 0.05554,
#   'chr13': 0.420561,
#   'chr14': 0.0,
#   'chr15': 0.61,
#   'chr16': 0.046951,
#   'chr17': 0.0,
#   'chr18': 0.117199,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'E_P_GBM454_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.0,
#   'chr3': 0.223011,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.090439,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.239796,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'E_R_GBM833_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.0,
#   'chr3': 0.223034,
#   'chr4': 0.020052,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.03348,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.376585,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.180576},
#  'F_P_GBM460_DEL_burden_by_chrom': {'chr1': 1.96,
#   'chr2': 0.0,
#   'chr3': 0.195037,
#   'chr4': 12.48,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.062235,
#   'chr8': 0.416568,
#   'chr9': 0.0,
#   'chr10': 0.306359,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 87.61,
#   'chr15': 55.8,
#   'chr16': 14.8,
#   'chr17': 0.527384,
#   'chr18': 0.0,
#   'chr19': 0.23855,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'F_R_GBM492_DEL_burden_by_chrom': {'chr1': 5.11,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.0,
#   'chr8': 0.22,
#   'chr9': 0.0,
#   'chr10': 0.1,
#   'chr11': 0.0,
#   'chr12': 0.055029,
#   'chr13': 0.0,
#   'chr14': 87.13,
#   'chr15': 78.81,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'G_P_GBM401_DEL_burden_by_chrom': {'chr1': 0.11,
#   'chr2': 0.034638,
#   'chr3': 0.0,
#   'chr4': 0.064557,
#   'chr5': 6.707296,
#   'chr6': 0.0,
#   'chr7': 0.0,
#   'chr8': 0.0,
#   'chr9': 9.299602,
#   'chr10': 4.77,
#   'chr11': 0.0,
#   'chr12': 15.490912,
#   'chr13': 0.211008,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.110367,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.131207},
#  'G_RR_GBM551_DEL_burden_by_chrom': {'chr1': 0.11,
#   'chr2': 5.574623,
#   'chr3': 0.0,
#   'chr4': 0.064544,
#   'chr5': 7.031114,
#   'chr6': 51.73,
#   'chr7': 0.0,
#   'chr8': 0.112187,
#   'chr9': 27.949591,
#   'chr10': 44.47,
#   'chr11': 0.0,
#   'chr12': 15.500912,
#   'chr13': 53.162032,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 16.15,
#   'chr18': 0.0,
#   'chr19': 0.182105,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.105291},
#  'G_R_GBM498_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 5.574639,
#   'chr3': 0.0,
#   'chr4': 0.064532,
#   'chr5': 7.081742,
#   'chr6': 51.72,
#   'chr7': 0.0,
#   'chr8': 0.112214,
#   'chr9': 27.949612,
#   'chr10': 59.21,
#   'chr11': 0.0,
#   'chr12': 17.305453,
#   'chr13': 53.07,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 26.29,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.180527},
#  'H_P_GBM529_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.0,
#   'chr3': 0.195067,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 1.109854,
#   'chr7': 0.019395,
#   'chr8': 0.0,
#   'chr9': 4.85,
#   'chr10': 0.0,
#   'chr11': 0.055148,
#   'chr12': 0.0,
#   'chr13': 1.15,
#   'chr14': 0.0,
#   'chr15': 0.08,
#   'chr16': 0.18,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 1.43,
#   'chrX': 0.126118},
#  'H_R_GBM832_DEL_burden_by_chrom': {'chr1': 68.79,
#   'chr2': 0.0,
#   'chr3': 0.058755,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 94.4,
#   'chr7': 0.0,
#   'chr8': 38.66,
#   'chr9': 103.865491,
#   'chr10': 48.47,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 67.58,
#   'chr14': 87.19,
#   'chr15': 0.0,
#   'chr16': 0.53,
#   'chr17': 0.2,
#   'chr18': 0.0,
#   'chr19': 16.49,
#   'chr20': 0.09,
#   'chr21': 0.0,
#   'chr22': 32.4,
#   'chrX': 0.0},
#  'I_P_BT2013110_DEL_burden_by_chrom': {'chr1': 0.11,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.0,
#   'chr8': 0.0,
#   'chr9': 1.99,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.055571,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.044359,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.259126,
#   'chr20': 0.0,
#   'chr21': 0.86,
#   'chr22': 0.0,
#   'chrX': 0.159054},
#  'I_R_GBM745_DEL_burden_by_chrom': {'chr1': 0.127302,
#   'chr2': 0.0,
#   'chr3': 7.6,
#   'chr4': 0.0233,
#   'chr5': 0.030297,
#   'chr6': 0.0,
#   'chr7': 0.0,
#   'chr8': 3.74,
#   'chr9': 25.86,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 5.62,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.044385,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.096186,
#   'chr20': 0.0,
#   'chr21': 0.9,
#   'chr22': 0.0,
#   'chrX': 0.142031},
#  'J_P_GBM703_DEL_burden_by_chrom': {'chr1': 0.11,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.051138,
#   'chr6': 0.0,
#   'chr7': 0.0,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.052128,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.1,
#   'chrX': 0.0},
#  'J_R_SMTB781_DEL_burden_by_chrom': {'chr1': 0.11,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.110728,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.05221,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.16035,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'X_P_GBM440_DEL_burden_by_chrom': {'chr1': 0.983965,
#   'chr2': 2.85,
#   'chr3': 4.72,
#   'chr4': 0.070866,
#   'chr5': 0.217452,
#   'chr6': 0.32,
#   'chr7': 0.4,
#   'chr8': 0.0,
#   'chr9': 14.57,
#   'chr10': 7.609309,
#   'chr11': 0.0,
#   'chr12': 0.164308,
#   'chr13': 82.97,
#   'chr14': 67.13,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'X_P_GBM577_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.320662,
#   'chr6': 0.0,
#   'chr7': 0.349842,
#   'chr8': 0.0,
#   'chr9': 27.04,
#   'chr10': 0.065053,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 34.5,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 8.56,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'X_P_GBM618_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.0,
#   'chr3': 0.05369,
#   'chr4': 2.64,
#   'chr5': 0.134037,
#   'chr6': 0.0,
#   'chr7': 0.0,
#   'chr8': 0.092192,
#   'chr9': 0.0,
#   'chr10': 0.18,
#   'chr11': 0.045456,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.10036,
#   'chr20': 0.0,
#   'chr21': 0.66,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'X_P_GBM672_DEL_burden_by_chrom': {'chr1': 0.545399,
#   'chr2': 0.411997,
#   'chr3': 0.0,
#   'chr4': 0.595607,
#   'chr5': 0.0,
#   'chr6': 8.39,
#   'chr7': 0.408225,
#   'chr8': 0.0,
#   'chr9': 3.383153,
#   'chr10': 5.589127,
#   'chr11': 0.033151,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 5.07,
#   'chr17': 0.057098,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'X_P_SMTB123_DEL_burden_by_chrom': {'chr1': 10.25542,
#   'chr2': 1.588246,
#   'chr3': 0.21,
#   'chr4': 0.0,
#   'chr5': 29.06,
#   'chr6': 2.424546,
#   'chr7': 0.0,
#   'chr8': 0.09473,
#   'chr9': 9.04,
#   'chr10': 84.63,
#   'chr11': 10.98,
#   'chr12': 0.0,
#   'chr13': 40.66,
#   'chr14': 39.955898,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.15,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'X_R_GBM945_DEL_burden_by_chrom': {'chr1': 5.574355,
#   'chr2': 0.0,
#   'chr3': 0.240311,
#   'chr4': 16.93,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.0,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 104.267899,
#   'chr11': 0.229379,
#   'chr12': 0.0,
#   'chr13': 67.33,
#   'chr14': 33.06,
#   'chr15': 73.73,
#   'chr16': 0.062039,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 48.64,
#   'chr20': 0.09,
#   'chr21': 0.0,
#   'chr22': 29.46,
#   'chrX': 0.0},
#  'X_R_SMTB135_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.233053,
#   'chr6': 0.0,
#   'chr7': 0.0,
#   'chr8': 0.0,
#   'chr9': 3.637984,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.520478,
#   'chr18': 0.305822,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'X_R_SMTB241_DEL_burden_by_chrom': {'chr1': 15.417061,
#   'chr2': 0.670353,
#   'chr3': 3.498606,
#   'chr4': 0.0,
#   'chr5': 0.141106,
#   'chr6': 25.334068,
#   'chr7': 0.458926,
#   'chr8': 3.18371,
#   'chr9': 20.77,
#   'chr10': 0.13,
#   'chr11': 0.654058,
#   'chr12': 0.071477,
#   'chr13': 49.8,
#   'chr14': 8.3,
#   'chr15': 10.67,
#   'chr16': 4.41,
#   'chr17': 0.311414,
#   'chr18': 0.233795,
#   'chr19': 6.966622,
#   'chr20': 0.19813,
#   'chr21': 0.0,
#   'chr22': 15.62,
#   'chrX': 0.26},
#  'X_R_SMTB302_DEL_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.0,
#   'chr3': 0.195055,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.033433,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.220095,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.03375,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.292324,
#   'chrX': 0.18054},
#  'X_R_SMTB814_DEL_burden_by_chrom': {'chr1': 0.23509,
#   'chr2': 0.179217,
#   'chr3': 3.12,
#   'chr4': 2.90507,
#   'chr5': 0.0,
#   'chr6': 0.12,
#   'chr7': 0.0,
#   'chr8': 0.0,
#   'chr9': 0.06,
#   'chr10': 103.57,
#   'chr11': 45.475509,
#   'chr12': 0.287269,
#   'chr13': 0.0,
#   'chr14': 2.228831,
#   'chr15': 3.020679,
#   'chr16': 0.0,
#   'chr17': 6.53,
#   'chr18': 0.0,
#   'chr19': 0.18,
#   'chr20': 0.069283,
#   'chr21': 0.0,
#   'chr22': 31.64,
#   'chrX': 0.0}}

# %%
for chrom in chromosomes:
    
    print(chrom)
    temp_low_burden_by_chrom = []
    temp_high_burden_by_chrom = []
    
    ###
    for s_id in low_burden_sample_id:
        
        temp_low_burden_by_chrom.append(large_DEL_burden_per_chrom_dicts[s_id + '_DEL_burden_by_chrom'][chrom])
    
    ###
    for s_id in high_burden_sample_id:
        
        temp_high_burden_by_chrom.append(large_DEL_burden_per_chrom_dicts[s_id + '_DEL_burden_by_chrom'][chrom])

        
    # Check for normality
    _, p1 = stats.shapiro(temp_low_burden_by_chrom)
    _, p2 = stats.shapiro(temp_high_burden_by_chrom)
    print("Normality Test P-values: Group1 =", p1, ", Group2 =", p2)

    # Check for equal variances
    _, p_levene = stats.levene(temp_low_burden_by_chrom, temp_high_burden_by_chrom)
    print("Levene's Test P-value:", p_levene)
# Out:
# chr1
# Normality Test P-values: Group1 = 7.463747806468746e-07 , Group2 = 8.446178298981977e-07
# Levene's Test P-value: 0.14459729720531458
# chr2
# Normality Test P-values: Group1 = 1.1264031485325177e-07 , Group2 = 2.0518269593594596e-05
# Levene's Test P-value: 0.0764250403237676
# chr3
# Normality Test P-values: Group1 = 1.7783443126972998e-06 , Group2 = 2.734838744800072e-05
# Levene's Test P-value: 0.13155678618283045
# chr4
# Normality Test P-values: Group1 = 8.183802719941013e-07 , Group2 = 1.4396158576346352e-06
# Levene's Test P-value: 0.35641511670081594
# chr5
# Normality Test P-values: Group1 = 1.5327399523812346e-05 , Group2 = 1.77468677975412e-06
# Levene's Test P-value: 0.11513821532159305
# chr6
# Normality Test P-values: Group1 = 3.167109809965041e-07 , Group2 = 2.1805819415021688e-05
# Levene's Test P-value: 0.05127553806872009
# chr7
# Normality Test P-values: Group1 = 0.00045475998194888234 , Group2 = 2.6511845135246404e-05
# Levene's Test P-value: 0.49817300347486937
# chr8
# Normality Test P-values: Group1 = 9.834303682509926e-08 , Group2 = 1.3116317632011487e-07
# Levene's Test P-value: 0.25110009217953744
# chr9
# Normality Test P-values: Group1 = 1.4983183064032346e-05 , Group2 = 4.671645365306176e-05
# Levene's Test P-value: 0.023786024600299247
# chr10
# Normality Test P-values: Group1 = 8.102553692879155e-06 , Group2 = 0.0005141861038282514
# Levene's Test P-value: 0.005297035031524696
# chr11
# Normality Test P-values: Group1 = 7.656117304577492e-06 , Group2 = 1.876828861213653e-07
# Levene's Test P-value: 0.3511847029941406
# chr12
# Normality Test P-values: Group1 = 2.548521251810598e-06 , Group2 = 8.791896107140929e-06
# Levene's Test P-value: 0.051377271584443315
# chr13
# Normality Test P-values: Group1 = 0.0004632772761397064 , Group2 = 0.0007884885417297482
# Levene's Test P-value: 0.0037923999139360715
# chr14
# Normality Test P-values: Group1 = 1.9984570087672182e-07 , Group2 = 0.0002135276881745085
# Levene's Test P-value: 0.00839780641085485
# chr15
# Normality Test P-values: Group1 = 3.2582574931439012e-06 , Group2 = 3.046675556106493e-05
# Levene's Test P-value: 0.03732751020611716
# chr16
# Normality Test P-values: Group1 = 4.4449839151639026e-06 , Group2 = 1.3953357438367675e-06
# Levene's Test P-value: 0.1404866928678984
# chr17
# Normality Test P-values: Group1 = 9.834303682509926e-08 , Group2 = 2.0257700725778705e-06
# Levene's Test P-value: 0.12019541365267457
# chr18
# Normality Test P-values: Group1 = 3.139751424896531e-05 , Group2 = 4.409453424614185e-07
# Levene's Test P-value: 0.3958382133461369
# chr19
# Normality Test P-values: Group1 = 0.00012259148934390396 , Group2 = 1.5048553905216977e-06
# Levene's Test P-value: 0.1280419004305316
# chr20
# Normality Test P-values: Group1 = 9.834303682509926e-08 , Group2 = 9.766171388037037e-06
# Levene's Test P-value: 0.15421806710433106
# chr21
# Normality Test P-values: Group1 = 4.038209340251342e-07 , Group2 = 3.6233956279829727e-07
# Levene's Test P-value: 0.5437210731463735
# chr22
# Normality Test P-values: Group1 = 4.6384280949496315e-07 , Group2 = 9.187364412355237e-06
# Levene's Test P-value: 0.05053878494389215
# chrX
# Normality Test P-values: Group1 = 0.00011126681783935055 , Group2 = 0.001099797897040844
# Levene's Test P-value: 0.27174639622556773

# %% [markdown]
# ## Large duplications

# %%
### Load filtered large duplications ###

##
somatic_large_DUP_path = '/Users/ryanyutian/Desktop/Manuscript/filtered_sv/DUP/'

somatic_large_DUP_dfs = {}

os.chdir(somatic_large_DUP_path)

temp_files = sorted([i for i in os.listdir(somatic_large_DUP_path) if 'DS' not in i])

for file_name in temp_files:
        
    somatic_large_DUP_dfs[file_name[:-4]] = pd.read_csv(file_name)

# %%
large_DUP_burden_per_chrom_dicts = {}

for df_name in somatic_large_DUP_dfs:
    
    temp_output_dict = {}
    
    temp_df = somatic_large_DUP_dfs[df_name]
    
    for chrom in chromosomes:
        
        temp_chrom_df = temp_df[temp_df['CHROM']==chrom]
        
        temp_output_dict[chrom] = calculate_total_coverage(temp_chrom_df)/1e6
        
    large_DUP_burden_per_chrom_dicts[df_name + '_burden_by_chrom'] = temp_output_dict

# %%
large_DUP_burden_per_chrom_dicts
# Out:
# {'A_RR_GBM809_DUP_burden_by_chrom': {'chr1': 0.290325,
#   'chr2': 0.0,
#   'chr3': 0.257371,
#   'chr4': 0.130862,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.0,
#   'chr8': 42.5,
#   'chr9': 0.080986,
#   'chr10': 0.313059,
#   'chr11': 0.0,
#   'chr12': 25.752292,
#   'chr13': 1.503271,
#   'chr14': 0.128279,
#   'chr15': 0.049213,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.107808,
#   'chrX': 0.0},
#  'A_R_GBM607_DUP_burden_by_chrom': {'chr1': 0.65978,
#   'chr2': 0.11,
#   'chr3': 0.1,
#   'chr4': 0.227174,
#   'chr5': 0.0,
#   'chr6': 0.159595,
#   'chr7': 41.61,
#   'chr8': 0.0,
#   'chr9': 0.3446,
#   'chr10': 0.08,
#   'chr11': 0.271498,
#   'chr12': 0.21891,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.474321,
#   'chr16': 0.0,
#   'chr17': 0.28,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.056502,
#   'chr21': 0.0,
#   'chr22': 0.09,
#   'chrX': 0.154345},
#  'B_P_GBM593_DUP_burden_by_chrom': {'chr1': 0.483589,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.147604,
#   'chr7': 2.483698,
#   'chr8': 0.171511,
#   'chr9': 0.0,
#   'chr10': 0.54555,
#   'chr11': 0.139723,
#   'chr12': 0.0,
#   'chr13': 29.59,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.302502,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.128884,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 1.470555},
#  'B_R_GBM898_DUP_burden_by_chrom': {'chr1': 0.408073,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.144493,
#   'chr5': 0.134853,
#   'chr6': 0.0,
#   'chr7': 0.16,
#   'chr8': 0.415166,
#   'chr9': 0.0,
#   'chr10': 0.448899,
#   'chr11': 0.345217,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.10826,
#   'chr15': 0.0,
#   'chr16': 0.301862,
#   'chr17': 0.23,
#   'chr18': 0.0,
#   'chr19': 0.18922,
#   'chr20': 0.0,
#   'chr21': 0.290547,
#   'chr22': 0.09,
#   'chrX': 0.981272},
#  'C_RR_GBM937_DUP_burden_by_chrom': {'chr1': 0.853638,
#   'chr2': 0.13,
#   'chr3': 0.275297,
#   'chr4': 0.160016,
#   'chr5': 0.624877,
#   'chr6': 0.249296,
#   'chr7': 10.55,
#   'chr8': 0.229366,
#   'chr9': 0.34,
#   'chr10': 26.05,
#   'chr11': 0.622649,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.18,
#   'chr16': 0.228443,
#   'chr17': 0.0,
#   'chr18': 0.26,
#   'chr19': 1.950404,
#   'chr20': 0.0,
#   'chr21': 0.156857,
#   'chr22': 0.0,
#   'chrX': 0.047801},
#  'C_R_GBM781_DUP_burden_by_chrom': {'chr1': 0.5,
#   'chr2': 0.374499,
#   'chr3': 0.516145,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.424868,
#   'chr7': 0.794791,
#   'chr8': 0.194317,
#   'chr9': 0.23,
#   'chr10': 0.217344,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.22082,
#   'chr15': 0.198594,
#   'chr16': 0.0,
#   'chr17': 0.46,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.37,
#   'chrX': 0.074111},
#  'D_P_GBM620_DUP_burden_by_chrom': {'chr1': 0.179977,
#   'chr2': 0.342211,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.061588,
#   'chr6': 0.0,
#   'chr7': 0.839062,
#   'chr8': 0.0,
#   'chr9': 0.257036,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.086,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.07,
#   'chr16': 0.109606,
#   'chr17': 0.0,
#   'chr18': 0.167356,
#   'chr19': 0.163903,
#   'chr20': 0.0,
#   'chr21': 0.051091,
#   'chr22': 0.0,
#   'chrX': 0.272986},
#  'D_R_GBM691_DUP_burden_by_chrom': {'chr1': 29.212513,
#   'chr2': 0.202704,
#   'chr3': 0.155582,
#   'chr4': 0.0,
#   'chr5': 0.0616,
#   'chr6': 0.078506,
#   'chr7': 19.49,
#   'chr8': 0.0,
#   'chr9': 0.1,
#   'chr10': 0.0,
#   'chr11': 0.237838,
#   'chr12': 0.0,
#   'chr13': 0.484289,
#   'chr14': 0.0,
#   'chr15': 0.12,
#   'chr16': 0.286796,
#   'chr17': 0.08,
#   'chr18': 0.0,
#   'chr19': 22.19,
#   'chr20': 0.176622,
#   'chr21': 0.0,
#   'chr22': 0.44,
#   'chrX': 0.730805},
#  'E_P_GBM454_DUP_burden_by_chrom': {'chr1': 0.18,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.047904,
#   'chr7': 0.053923,
#   'chr8': 0.272536,
#   'chr9': 0.0,
#   'chr10': 0.104908,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.356176,
#   'chr17': 0.08,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.474484},
#  'E_R_GBM833_DUP_burden_by_chrom': {'chr1': 0.211236,
#   'chr2': 0.0,
#   'chr3': 0.0,
#   'chr4': 0.205633,
#   'chr5': 0.0,
#   'chr6': 0.117839,
#   'chr7': 133.46,
#   'chr8': 0.09,
#   'chr9': 0.0,
#   'chr10': 0.183891,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.161764,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.08381,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'F_P_GBM460_DUP_burden_by_chrom': {'chr1': 105.575524,
#   'chr2': 223.94,
#   'chr3': 0.0952,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.38772,
#   'chr8': 0.07,
#   'chr9': 1.133658,
#   'chr10': 0.13,
#   'chr11': 0.12148,
#   'chr12': 0.488909,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.16,
#   'chr17': 0.979955,
#   'chr18': 0.0,
#   'chr19': 0.724102,
#   'chr20': 0.17351,
#   'chr21': 0.0,
#   'chr22': 1.184299,
#   'chrX': 0.155059},
#  'F_R_GBM492_DUP_burden_by_chrom': {'chr1': 160.36737,
#   'chr2': 151.672893,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 0.377746,
#   'chr8': 0.21,
#   'chr9': 0.740041,
#   'chr10': 0.413693,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.07,
#   'chr17': 0.559785,
#   'chr18': 0.0,
#   'chr19': 1.069503,
#   'chr20': 0.198163,
#   'chr21': 0.416721,
#   'chr22': 0.83,
#   'chrX': 0.101713},
#  'G_P_GBM401_DUP_burden_by_chrom': {'chr1': 1.292131,
#   'chr2': 0.1,
#   'chr3': 0.45072,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 98.6,
#   'chr8': 0.06,
#   'chr9': 0.3,
#   'chr10': 0.0,
#   'chr11': 0.917885,
#   'chr12': 0.0,
#   'chr13': 0.190601,
#   'chr14': 0.7,
#   'chr15': 0.0,
#   'chr16': 0.218875,
#   'chr17': 0.145377,
#   'chr18': 0.0,
#   'chr19': 0.40986,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.11,
#   'chrX': 0.154094},
#  'G_RR_GBM551_DUP_burden_by_chrom': {'chr1': 0.76,
#   'chr2': 0.107872,
#   'chr3': 0.450722,
#   'chr4': 0.46864,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 144.59,
#   'chr8': 0.137728,
#   'chr9': 0.0,
#   'chr10': 0.238454,
#   'chr11': 1.041404,
#   'chr12': 0.0,
#   'chr13': 0.192432,
#   'chr14': 0.0,
#   'chr15': 0.51,
#   'chr16': 0.23,
#   'chr17': 0.14549,
#   'chr18': 0.0,
#   'chr19': 0.56497,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.11,
#   'chrX': 0.173266},
#  'G_R_GBM498_DUP_burden_by_chrom': {'chr1': 1.390639,
#   'chr2': 0.12,
#   'chr3': 0.450722,
#   'chr4': 0.0,
#   'chr5': 0.073379,
#   'chr6': 0.0,
#   'chr7': 150.13,
#   'chr8': 0.0,
#   'chr9': 0.34,
#   'chr10': 0.1,
#   'chr11': 0.917884,
#   'chr12': 0.318142,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.12,
#   'chr16': 0.06,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.086658,
#   'chr20': 0.410107,
#   'chr21': 0.066683,
#   'chr22': 0.0,
#   'chrX': 0.309484},
#  'H_P_GBM529_DUP_burden_by_chrom': {'chr1': 0.296433,
#   'chr2': 0.31,
#   'chr3': 0.0,
#   'chr4': 0.265442,
#   'chr5': 0.17,
#   'chr6': 0.06445,
#   'chr7': 1.317187,
#   'chr8': 0.0,
#   'chr9': 0.28,
#   'chr10': 0.0,
#   'chr11': 0.0,
#   'chr12': 0.057028,
#   'chr13': 0.0,
#   'chr14': 0.193178,
#   'chr15': 0.0,
#   'chr16': 0.462458,
#   'chr17': 0.39,
#   'chr18': 0.0,
#   'chr19': 0.234253,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 45.414803},
#  'H_R_GBM832_DUP_burden_by_chrom': {'chr1': 0.242621,
#   'chr2': 0.11,
#   'chr3': 0.0,
#   'chr4': 0.297837,
#   'chr5': 0.702906,
#   'chr6': 0.0,
#   'chr7': 1.690638,
#   'chr8': 0.0,
#   'chr9': 0.382429,
#   'chr10': 0.0,
#   'chr11': 0.225631,
#   'chr12': 0.040447,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.24,
#   'chr16': 0.63732,
#   'chr17': 0.28,
#   'chr18': 0.0,
#   'chr19': 0.086155,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 132.663838},
#  'I_P_BT2013110_DUP_burden_by_chrom': {'chr1': 0.0,
#   'chr2': 0.13,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 96.81,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.348296,
#   'chr11': 0.606373,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.3,
#   'chr16': 0.1,
#   'chr17': 0.859349,
#   'chr18': 0.0,
#   'chr19': 0.524743,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.0},
#  'I_R_GBM745_DUP_burden_by_chrom': {'chr1': 0.063591,
#   'chr2': 0.124638,
#   'chr3': 0.35095,
#   'chr4': 0.079552,
#   'chr5': 0.0,
#   'chr6': 0.0,
#   'chr7': 134.25,
#   'chr8': 0.18,
#   'chr9': 0.0,
#   'chr10': 0.18463,
#   'chr11': 0.161854,
#   'chr12': 0.244702,
#   'chr13': 0.0,
#   'chr14': 0.163842,
#   'chr15': 0.21,
#   'chr16': 0.1,
#   'chr17': 0.19,
#   'chr18': 0.0,
#   'chr19': 0.552712,
#   'chr20': 0.0,
#   'chr21': 0.500956,
#   'chr22': 0.216676,
#   'chrX': 0.446932},
#  'J_P_GBM703_DUP_burden_by_chrom': {'chr1': 0.511129,
#   'chr2': 0.11,
#   'chr3': 0.032529,
#   'chr4': 0.0,
#   'chr5': 0.070394,
#   'chr6': 0.520943,
#   'chr7': 64.26,
#   'chr8': 0.177318,
#   'chr9': 0.499242,
#   'chr10': 0.661907,
#   'chr11': 0.085293,
#   'chr12': 0.0,
#   'chr13': 0.097438,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.099973,
#   'chr17': 0.193346,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 9.2,
#   'chr21': 0.092804,
#   'chr22': 0.073361,
#   'chrX': 0.609227},
#  'J_R_SMTB781_DUP_burden_by_chrom': {'chr1': 0.22,
#   'chr2': 0.14,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.067627,
#   'chr6': 0.0,
#   'chr7': 0.285602,
#   'chr8': 0.113595,
#   'chr9': 0.19,
#   'chr10': 0.403726,
#   'chr11': 0.0,
#   'chr12': 0.217775,
#   'chr13': 0.0,
#   'chr14': 0.179712,
#   'chr15': 0.0,
#   'chr16': 0.0,
#   'chr17': 0.47,
#   'chr18': 0.0,
#   'chr19': 0.046264,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.0,
#   'chrX': 0.194029},
#  'X_P_GBM440_DUP_burden_by_chrom': {'chr1': 0.750117,
#   'chr2': 0.184128,
#   'chr3': 0.0,
#   'chr4': 0.0,
#   'chr5': 0.0,
#   'chr6': 0.04504,
#   'chr7': 0.0,
#   'chr8': 0.0,
#   'chr9': 0.45,
#   'chr10': 0.030312,
#   'chr11': 0.0,
#   'chr12': 0.0,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.355859,
#   'chr17': 0.662994,
#   'chr18': 0.0,
#   'chr19': 0.142651,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.14,
#   'chrX': 0.0},
#  'X_P_GBM577_DUP_burden_by_chrom': {'chr1': 0.324754,
#   'chr2': 0.0,
#   'chr3': 0.035005,
#   'chr4': 0.1659,
#   'chr5': 0.0,
#   'chr6': 0.170906,
#   'chr7': 138.84,
#   'chr8': 0.0,
#   'chr9': 0.0,
#   'chr10': 0.248363,
#   'chr11': 0.0,
#   'chr12': 0.24574,
#   'chr13': 0.0,
#   'chr14': 0.17,
#   'chr15': 41.22,
#   'chr16': 0.31,
#   'chr17': 0.199435,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.0,
#   'chr21': 21.11,
#   'chr22': 0.21,
#   'chrX': 0.0},
#  'X_P_GBM618_DUP_burden_by_chrom': {'chr1': 0.462474,
#   'chr2': 0.0,
#   'chr3': 0.040557,
#   'chr4': 0.2,
#   'chr5': 0.15709,
#   'chr6': 0.0,
#   'chr7': 0.633532,
#   'chr8': 0.0,
#   'chr9': 0.06,
#   'chr10': 0.750003,
#   'chr11': 0.32,
#   'chr12': 0.0,
#   'chr13': 0.05987,
#   'chr14': 0.065587,
#   'chr15': 0.06,
#   'chr16': 0.35,
#   'chr17': 0.428902,
#   'chr18': 0.055224,
#   'chr19': 0.325735,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.06,
#   'chrX': 0.177538},
#  'X_P_GBM672_DUP_burden_by_chrom': {'chr1': 9.342374,
#   'chr2': 0.208496,
#   'chr3': 0.200447,
#   'chr4': 0.485116,
#   'chr5': 0.0,
#   'chr6': 0.275478,
#   'chr7': 12.169001,
#   'chr8': 0.053872,
#   'chr9': 0.592465,
#   'chr10': 0.127891,
#   'chr11': 0.0,
#   'chr12': 0.118681,
#   'chr13': 0.0,
#   'chr14': 0.202604,
#   'chr15': 0.43,
#   'chr16': 0.187584,
#   'chr17': 0.257778,
#   'chr18': 0.0,
#   'chr19': 49.89,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.48569,
#   'chrX': 0.159108},
#  'X_P_SMTB123_DUP_burden_by_chrom': {'chr1': 0.192203,
#   'chr2': 0.097898,
#   'chr3': 0.031993,
#   'chr4': 0.389373,
#   'chr5': 5.71,
#   'chr6': 0.519892,
#   'chr7': 108.79417,
#   'chr8': 0.0,
#   'chr9': 0.579905,
#   'chr10': 0.321275,
#   'chr11': 0.0,
#   'chr12': 0.483806,
#   'chr13': 0.449585,
#   'chr14': 0.0,
#   'chr15': 0.988431,
#   'chr16': 0.590161,
#   'chr17': 0.701166,
#   'chr18': 0.0,
#   'chr19': 6.97,
#   'chr20': 27.972038,
#   'chr21': 0.0,
#   'chr22': 0.172017,
#   'chrX': 0.348434},
#  'X_R_GBM945_DUP_burden_by_chrom': {'chr1': 1.190885,
#   'chr2': 0.221849,
#   'chr3': 0.0,
#   'chr4': 0.106558,
#   'chr5': 0.0,
#   'chr6': 0.04686,
#   'chr7': 147.34,
#   'chr8': 0.39,
#   'chr9': 0.47,
#   'chr10': 0.0,
#   'chr11': 0.06,
#   'chr12': 0.0,
#   'chr13': 0.109555,
#   'chr14': 0.0,
#   'chr15': 0.0,
#   'chr16': 0.223798,
#   'chr17': 0.336413,
#   'chr18': 0.0,
#   'chr19': 0.122674,
#   'chr20': 0.0,
#   'chr21': 0.0,
#   'chr22': 0.1,
#   'chrX': 51.557981},
#  'X_R_SMTB135_DUP_burden_by_chrom': {'chr1': 0.11,
#   'chr2': 0.34778,
#   'chr3': 0.05127,
#   'chr4': 0.0,
#   'chr5': 0.10509,
#   'chr6': 0.0,
#   'chr7': 0.110245,
#   'chr8': 0.0,
#   'chr9': 0.321203,
#   'chr10': 0.0,
#   'chr11': 0.131729,
#   'chr12': 0.094711,
#   'chr13': 0.260584,
#   'chr14': 0.144353,
#   'chr15': 0.043722,
#   'chr16': 0.065245,
#   'chr17': 0.055721,
#   'chr18': 0.194414,
#   'chr19': 0.212145,
#   'chr20': 0.0,
#   'chr21': 0.128862,
#   'chr22': 0.0,
#   'chrX': 0.348585},
#  'X_R_SMTB241_DUP_burden_by_chrom': {'chr1': 2.5253,
#   'chr2': 0.074725,
#   'chr3': 1.832705,
#   'chr4': 61.990953,
#   'chr5': 16.610083,
#   'chr6': 0.736225,
#   'chr7': 77.391231,
#   'chr8': 0.151319,
#   'chr9': 0.0,
#   'chr10': 0.151266,
#   'chr11': 0.740629,
#   'chr12': 0.621912,
#   'chr13': 0.482354,
#   'chr14': 0.18918,
#   'chr15': 0.0,
#   'chr16': 16.89,
#   'chr17': 1.396251,
#   'chr18': 0.086002,
#   'chr19': 0.160153,
#   'chr20': 0.188934,
#   'chr21': 0.403331,
#   'chr22': 0.060851,
#   'chrX': 0.37659},
#  'X_R_SMTB302_DUP_burden_by_chrom': {'chr1': 1.01,
#   'chr2': 0.0,
#   'chr3': 0.20455,
#   'chr4': 0.31,
#   'chr5': 0.05562,
#   'chr6': 0.0,
#   'chr7': 0.125358,
#   'chr8': 0.032072,
#   'chr9': 0.100232,
#   'chr10': 0.0,
#   'chr11': 0.182772,
#   'chr12': 0.051496,
#   'chr13': 0.0,
#   'chr14': 0.0,
#   'chr15': 0.07,
#   'chr16': 0.0,
#   'chr17': 0.0,
#   'chr18': 0.0,
#   'chr19': 0.0,
#   'chr20': 0.153132,
#   'chr21': 0.075788,
#   'chr22': 0.0,
#   'chrX': 0.499687},
#  'X_R_SMTB814_DUP_burden_by_chrom': {'chr1': 0.348259,
#   'chr2': 0.0,
#   'chr3': 0.096766,
#   'chr4': 1.06,
#   'chr5': 0.362234,
#   'chr6': 0.0,
#   'chr7': 46.75,
#   'chr8': 0.49002,
#   'chr9': 0.12,
#   'chr10': 0.0,
#   'chr11': 0.748389,
#   'chr12': 0.16,
#   'chr13': 0.08405,
#   'chr14': 1.164066,
#   'chr15': 0.0,
#   'chr16': 0.147231,
#   'chr17': 1.566221,
#   'chr18': 0.0,
#   'chr19': 0.523193,
#   'chr20': 33.76,
#   'chr21': 0.0,
#   'chr22': 0.07,
#   'chrX': 0.504884}}

# %%
for chrom in chromosomes:
    
    print(chrom)
    temp_low_burden_by_chrom = []
    temp_high_burden_by_chrom = []
    
    ###
    for s_id in low_burden_sample_id:
        
        temp_low_burden_by_chrom.append(large_DUP_burden_per_chrom_dicts[s_id + '_DUP_burden_by_chrom'][chrom])
    
    ###
    for s_id in high_burden_sample_id:
        
        temp_high_burden_by_chrom.append(large_DUP_burden_per_chrom_dicts[s_id + '_DUP_burden_by_chrom'][chrom])

        
    # Check for normality
    _, p1 = stats.shapiro(temp_low_burden_by_chrom)
    _, p2 = stats.shapiro(temp_high_burden_by_chrom)
    print("Normality Test P-values: Group1 =", p1, ", Group2 =", p2)

    # Check for equal variances
    _, p_levene = stats.levene(temp_low_burden_by_chrom, temp_high_burden_by_chrom)
    print("Levene's Test P-value:", p_levene)
# Out:
# chr1
# Normality Test P-values: Group1 = 1.5219572446767415e-07 , Group2 = 7.429905508615775e-07
# Levene's Test P-value: 0.20949801110292296
# chr2
# Normality Test P-values: Group1 = 0.009495995938777924 , Group2 = 4.5185873887021444e-07
# Levene's Test P-value: 0.17722477047609705
# chr3
# Normality Test P-values: Group1 = 0.0015538940206170082 , Group2 = 1.038954269461101e-05
# Levene's Test P-value: 0.23689915878594459
# chr4
# Normality Test P-values: Group1 = 0.0029284891206771135 , Group2 = 5.58404771311416e-08
# Levene's Test P-value: 0.32863664408772175
# chr5
# Normality Test P-values: Group1 = 3.4795441024471074e-05 , Group2 = 3.7525973084484576e-07
# Levene's Test P-value: 0.2206776150328749
# chr6
# Normality Test P-values: Group1 = 0.0006133818533271551 , Group2 = 3.583873331081122e-05
# Levene's Test P-value: 0.8823018821357516
# chr7
# Normality Test P-values: Group1 = 1.8091748643200845e-05 , Group2 = 0.009823385626077652
# Levene's Test P-value: 0.00024451234613785905
# chr8
# Normality Test P-values: Group1 = 1.1297577628965882e-07 , Group2 = 0.0018640125636011362
# Levene's Test P-value: 0.30807669733254495
# chr9
# Normality Test P-values: Group1 = 0.2802012264728546 , Group2 = 0.026669878512620926
# Levene's Test P-value: 0.0134877530100922
# chr10
# Normality Test P-values: Group1 = 1.5991818713700923e-07 , Group2 = 0.1974908709526062
# Levene's Test P-value: 0.27790742065415597
# chr11
# Normality Test P-values: Group1 = 0.011880272999405861 , Group2 = 0.0020477576181292534
# Levene's Test P-value: 0.03394898519147829
# chr12
# Normality Test P-values: Group1 = 1.1111645648043122e-07 , Group2 = 0.003517528995871544
# Levene's Test P-value: 0.34237257343056304
# chr13
# Normality Test P-values: Group1 = 1.5208722459192359e-07 , Group2 = 5.4473875934490934e-05
# Levene's Test P-value: 0.2920440051130793
# chr14
# Normality Test P-values: Group1 = 0.002271471545100212 , Group2 = 9.802483873500023e-06
# Levene's Test P-value: 0.29057689887282845
# chr15
# Normality Test P-values: Group1 = 0.00023536755179520696 , Group2 = 6.067359237249548e-08
# Levene's Test P-value: 0.3206403960129356
# chr16
# Normality Test P-values: Group1 = 0.032751306891441345 , Group2 = 7.399742685265664e-08
# Levene's Test P-value: 0.3522850514404928
# chr17
# Normality Test P-values: Group1 = 0.01106429472565651 , Group2 = 0.0398758165538311
# Levene's Test P-value: 0.044770590168528024
# chr18
# Normality Test P-values: Group1 = 2.1268233467708342e-05 , Group2 = 4.553090349190825e-08
# Levene's Test P-value: 0.08665231562431737
# chr19
# Normality Test P-values: Group1 = 1.995880438698805e-07 , Group2 = 1.3203610649270558e-07
# Levene's Test P-value: 0.5593208823356628
# chr20
# Normality Test P-values: Group1 = 1.284449950844646e-07 , Group2 = 4.787064540323627e-07
# Levene's Test P-value: 0.25070515145969013
# chr21
# Normality Test P-values: Group1 = 0.00027488870546221733 , Group2 = 6.250252937434198e-08
# Levene's Test P-value: 0.32769235961611565
# chr22
# Normality Test P-values: Group1 = 6.632228178204969e-05 , Group2 = 0.0001332984829787165
# Levene's Test P-value: 0.2186721051827146
# chrX
# Normality Test P-values: Group1 = 1.4948892612665077e-07 , Group2 = 3.136603936582105e-07
# Levene's Test P-value: 0.38371650632469023

# %%
temp_low_burden_by_chrom_dict = {}
temp_high_burden_by_chrom_dict = {}

for s_id in low_burden_sample_id:

    temp_low_burden_by_chrom_dict[s_id] = 0
    
for s_id in high_burden_sample_id:

    temp_high_burden_by_chrom_dict[s_id] = 0

for s_id in low_burden_sample_id:
    
    for chrom in ['chr9', 'chr10', 'chr13', 'chr14', 'chr15']:

        temp_low_burden_by_chrom_dict[s_id] += large_DEL_burden_per_chrom_dicts[s_id + '_DEL_burden_by_chrom'][chrom]

for s_id in high_burden_sample_id:
    
    for chrom in ['chr9', 'chr10', 'chr13', 'chr14', 'chr15']:

        temp_high_burden_by_chrom_dict[s_id] += large_DEL_burden_per_chrom_dicts[s_id + '_DEL_burden_by_chrom'][chrom]

temp_low_burden_by_chrom = [temp_low_burden_by_chrom_dict[i] for i in temp_low_burden_by_chrom_dict]
temp_high_burden_by_chrom = [temp_high_burden_by_chrom_dict[i] for i in temp_high_burden_by_chrom_dict]

# Perform T-test
t_stat, p_value = stats.ttest_ind(temp_low_burden_by_chrom, temp_high_burden_by_chrom, equal_var=False)
print("t-statistic:", t_stat)
print("p-value:", p_value)

# Create a figure and a set of subplots
fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
mpl.rcParams['font.family'] = 'sans-serif'

# Define data for plotting
data = [temp_low_burden_by_chrom, temp_high_burden_by_chrom]
positions = [1.5, 2.5]
labels = ['Low SV Burden\nSamples', 'High SV Burden\nSamples']
colors = ['blue', 'blue']

# Add box plot
box = ax.boxplot(data, positions=positions, widths=0.4, patch_artist=True, showfliers=False, 
                 boxprops=dict(facecolor='darkgray', color='black', alpha=0.5, linewidth=2),
                 medianprops=dict(color='black', linewidth=2),
                 whiskerprops=dict(color='black', linewidth=2),
                 capprops=dict(color='none'))

# Add scatter plot 
for pos, single_data, color in zip(positions, data, colors):
    jitter = np.random.normal(pos, 0.05, size=len(single_data))
    ax.scatter(jitter, single_data, color=color, zorder=2)
    
# Styling and labels
ax.set_title('SV Burden Deletions (Mb)\nCombined chr9, 10, 13, 14, 15', weight='bold', pad=10)
ax.set_xticks(positions)
ax.set_xticklabels(labels, weight='bold')

# Adjust axis limits
ax.set_xlim(1, 3)
ax.set_ylim(-10, 401)
ax.set_yticks(range(0, 401, 100))

# Increase the distance between the xticklabels and the plot
ax.tick_params(axis='x', pad=10)

# Add significance bracket
x1, x2 = positions
y, h, col = 360, 5, 'k'  # Y-coordinate, height, and color
ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
ax.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)

plt.tight_layout()
fig.savefig('/Users/ryanyutian/Desktop/Manuscript/driver_heatmap/burden_comparison/del_combined.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# t-statistic: -4.7290343419471945
# p-value: 0.0002671694537938835

# %%
chrom = 'chr7'

temp_low_burden_by_chrom = []
temp_high_burden_by_chrom = []

###
for s_id in low_burden_sample_id:

    temp_low_burden_by_chrom.append(large_DUP_burden_per_chrom_dicts[s_id + '_DUP_burden_by_chrom'][chrom])

###
for s_id in high_burden_sample_id:

    temp_high_burden_by_chrom.append(large_DUP_burden_per_chrom_dicts[s_id + '_DUP_burden_by_chrom'][chrom])

# Perform T-test
t_stat, p_value = stats.ttest_ind(temp_low_burden_by_chrom, temp_high_burden_by_chrom, equal_var=False)
print("t-statistic:", t_stat)
print("p-value:", p_value)

# Create a figure and a set of subplots
fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
mpl.rcParams['font.family'] = 'sans-serif'

# Define data for plotting
data = [temp_low_burden_by_chrom, temp_high_burden_by_chrom]
positions = [1.5, 2.5]  
labels = ['Low SV Burden\nSamples', 'High SV Burden\nSamples']
colors = ['red', 'red']

# Add box plot
box = ax.boxplot(data, positions=positions, widths=0.4, patch_artist=True, showfliers=False, 
                 boxprops=dict(facecolor='darkgray', color='black', alpha=0.5, linewidth=2),
                 medianprops=dict(color='black', linewidth=2),
                 whiskerprops=dict(color='black', linewidth=2),
                 capprops=dict(color='none'))

# Add scatter plot 
for pos, single_data, color in zip(positions, data, colors):
    jitter = np.random.normal(pos, 0.05, size=len(single_data))
    ax.scatter(jitter, single_data, color=color, zorder=2)

# Styling and labels
ax.set_title('SV Burden Duplications (Mb)\nChromosome 7', weight='bold', pad=10) 
ax.set_xticks(positions)
ax.set_xticklabels(labels, weight='bold')

# Adjust axis limits
ax.set_xlim(1, 3)
ax.set_ylim(-10, 200)
ax.set_yticks(range(0, 201, 50))
ax.tick_params(axis='x', pad=10)

# Add significance bracket
x1, x2 = positions
y, h, col = 180, 2.5, 'k'  # Y-coordinate, height, and color
ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
ax.text((x1+x2)*.5, y+h, "*", ha='center', va='bottom', color=col)

plt.tight_layout()
plt.show()
fig.savefig('/Users/ryanyutian/Desktop/Manuscript/driver_heatmap/burden_comparison/dup_chr7.png', dpi=300, bbox_inches='tight')
# Out:
# t-statistic: -4.467370463990419
# p-value: 0.00029554679026626225
